# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv("/content/drive/MyDrive/Pune/Datasets/startup_funding.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3044 entries, 0 to 3043
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sr No              3044 non-null   int64
#  1   Date dd/mm/yyyy    3044 non-null   object
#  2   Startup Name       3044 non-null   object
#  3   Industry Vertical  2873 non-null   object
#  4   SubVertical        2108 non-null   object
#  5   City  Location     2864 non-null   object
#  6   Investors Name     3020 non-null   object
#  7   InvestmentnType    3040 non-null   object
#  8   Amount in USD      2084 non-null   object
#  9   Remarks            419 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 237.9+ KB

# %%
df.sample(4)
# Out:
#       Sr No Date dd/mm/yyyy  Startup Name             Industry Vertical  \
# 1489   1490      29/08/2016  Notion Press             Consumer Internet
# 247     248      22/06/2018    WickedRide             Consumer Internet
# 232     233      10/06/2018    AyeFinance                       Finance
# 2285   2286      30/11/2015       MoMagic  Mobile Application Developer
#
#                                         SubVertical City  Location  \
# 1489                 Self-Publishing books platform        Chennai
# 247   Online Motorbike And Scooter Rental Platforms      Bengaluru
# 232                         Online Lending Platform       Gurugram
# 2285                                            NaN      New Delhi
#
#                                          Investors Name InvestmentnType  \
# 1489                          Undisclosed HNI investors  Private Equity
# 247   Sequoia Capital, Accel Partners & Raghunandan ...  Private Equity
# ...

# %%
df['Remarks'].value_counts()
# Out:
# Remarks
# Series A                             175
# Series B                              63
# Pre-Series A                          37
# Series C                              28
# Series D                              11
#                                     ...
# Pre Series-A                           1
# QPrize Contest Winners                 1
# pre-series A                           1
# Personal Investment                    1
# Strategic Funding, Minority stake      1
# Name: count, Length: 72, dtype: int64

# %%
df.drop(columns =['Remarks'],inplace = True)

# %%
df.sample(3)
# Out:
#       Sr No Date dd/mm/yyyy      Startup Name          Industry Vertical  \
# 414     415      24/01/2018  NeoGrowth Credit                    Finance
# 1798   1799      21/04/2016           mishTag          Consumer Internet
# 2575   2576      02/07/2015        BankBazaar  Online Financial Services
#
#                               SubVertical City  Location  \
# 414                       Digital Lending         Mumbai
# 1798  Style, Fashion Discovery Mobile app      New Delhi
# 2575                                  NaN        Chennai
#
#                                          Investors Name InvestmentnType  \
# 414   LeapFrog Investments, Aspada Investment, Quona...  Private Equity
# 1798  M&Y Partners, SVG Media, Anthil Ventures & others    Seed Funding
# 2575  Amazon, Fidelity Growth Partners, Mousse Partners  Private Equity
#
#      Amount in USD
# 414    4,70,00,000
# 1798           NaN
# 2575   6,00,00,000

# %%
df
# Out:
#       Sr No Date dd/mm/yyyy                  Startup Name  \
# 0         1      09/01/2020                        BYJU’S
# 1         2      13/01/2020                        Shuttl
# 2         3      09/01/2020                     Mamaearth
# 3         4      02/01/2020  https://www.wealthbucket.in/
# 4         5      02/01/2020                        Fashor
# ...     ...             ...                           ...
# 3039   3040      29/01/2015                    Printvenue
# 3040   3041      29/01/2015                      Graphene
# 3041   3042      30/01/2015                Mad Street Den
# 3042   3043      30/01/2015                     Simplotel
# 3043   3044      31/01/2015              couponmachine.in
#
#         Industry Vertical                            SubVertical  \
# 0                  E-Tech                             E-learning
# 1          Transportation              App based shuttle service
# 2              E-commerce  Retailer of baby and toddler products
# ...

# %%
df.set_index('Sr No' , inplace = True)

# %%
df.shape
# Out:
# (3044, 8)

# %%
df
# Out:
#       Date dd/mm/yyyy                  Startup Name    Industry Vertical  \
# Sr No
# 1          09/01/2020                        BYJU’S               E-Tech
# 2          13/01/2020                        Shuttl       Transportation
# 3          09/01/2020                     Mamaearth           E-commerce
# 4          02/01/2020  https://www.wealthbucket.in/              FinTech
# 5          02/01/2020                        Fashor  Fashion and Apparel
# ...               ...                           ...                  ...
# 3040       29/01/2015                    Printvenue                  NaN
# 3041       29/01/2015                      Graphene                  NaN
# 3042       30/01/2015                Mad Street Den                  NaN
# 3043       30/01/2015                     Simplotel                  NaN
# 3044       31/01/2015              couponmachine.in                  NaN
#
#                                  SubVertical City  Location  \
# Sr No
# ...

# %%
df.rename(columns= {
    'Date dd/mm/yyyy' : 'date',
    'Startup Name': 'startup',
    'Industry Vertical': 'vertical',
    'SubVertical' :'subvertical',
    'City  Location': 'city',
    'Investors Name' : 'investor',
    'InvestmentnType': 'round',
    'Amount in USD' :'amount'

},inplace =True)

# %%
df.head()
# Out:
#              date                       startup             vertical  \
# Sr No
# 1      09/01/2020                        BYJU’S               E-Tech
# 2      13/01/2020                        Shuttl       Transportation
# 3      09/01/2020                     Mamaearth           E-commerce
# 4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 5      02/01/2020                        Fashor  Fashion and Apparel
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
# 4                          Online Investment  New Delhi
# 5                Embroiled Clothes For Women     Mumbai
#
#                         investor                 round        amount
# Sr No
# 1        Tiger Global Management  Private Equity Round  20,00,00,000
# ...

# %%
df['vertical'].value_counts().head(3)
# Out:
# vertical
# Consumer Internet    941
# Technology           478
# eCommerce            186
# Name: count, dtype: int64

# %%
df['subvertical'].value_counts().head(3)
# Out:
# subvertical
# Online Lending Platform    11
# Online Pharmacy            10
# Food Delivery Platform      8
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (3044, 8)

# %%
#null values
df.isnull().sum()
# Out:
# date             0
# startup          0
# vertical       171
# subvertical    936
# city           180
# investor        24
# round            4
# amount         960
# dtype: int64

# %%
df['amount']
# Out:
# Sr No
# 1       20,00,00,000
# 2          80,48,394
# 3        1,83,58,860
# 4          30,00,000
# 5          18,00,000
#             ...
# 3040       45,00,000
# 3041        8,25,000
# 3042       15,00,000
# 3043             NaN
# 3044        1,40,000
# Name: amount, Length: 3044, dtype: object

# %%
df.isnull().sum()
# Out:
# date             0
# startup          0
# vertical       171
# subvertical    936
# city           180
# investor        24
# round            4
# amount         960
# dtype: int64

# %%
df['amount'] = df['amount'].str.replace(',','')

# %%
df['amount'] = df['amount'].str.replace('undisclosed','0')

# %%
df['amount'] = df['amount'].str.replace('unknown','0')

# %%
df['amount'] = df['amount'].str.replace('Undisclosed','0')

# %%
df['amount'] = df['amount'].str.replace('NAN','')

# %%
df['amount'] = pd.to_numeric(df['amount'], errors='coerce')

# %%
df['amount'] = df['amount'].fillna(df['amount'].mean()) #Filling the missing values with the mean

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3044 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3044 non-null   object
#  1   startup      3044 non-null   object
#  2   vertical     2873 non-null   object
#  3   subvertical  2108 non-null   object
#  4   city         2864 non-null   object
#  5   investor     3020 non-null   object
#  6   round        3040 non-null   object
#  7   amount       3044 non-null   float64
# dtypes: float64(1), object(7)
# memory usage: 214.0+ KB

# %%
df.isnull().sum()
# Out:
# date             0
# startup          0
# vertical       171
# subvertical    936
# city           180
# investor        24
# round            4
# amount           0
# dtype: int64

# %%
def to_inr(dollar):
  inr = dollar * 84.36
  return inr/10000000

# %%
to_inr(400000)
# Out:
# 3.3744

# %%
df['amount']= df['amount'].apply(to_inr)

# %%
df.head()
# Out:
#              date                       startup             vertical  \
# Sr No
# 1      09/01/2020                        BYJU’S               E-Tech
# 2      13/01/2020                        Shuttl       Transportation
# 3      09/01/2020                     Mamaearth           E-commerce
# 4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 5      02/01/2020                        Fashor  Fashion and Apparel
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
# 4                          Online Investment  New Delhi
# 5                Embroiled Clothes For Women     Mumbai
#
#                         investor                 round       amount
# Sr No
# 1        Tiger Global Management  Private Equity Round  1687.200000
# ...

# %%
df['date'] =  pd.to_datetime(df['date'],format='%d/%m/%Y' ,errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3044 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3036 non-null   datetime64[ns]
#  1   startup      3044 non-null   object
#  2   vertical     2873 non-null   object
#  3   subvertical  2108 non-null   object
#  4   city         2864 non-null   object
#  5   investor     3020 non-null   object
#  6   round        3040 non-null   object
#  7   amount       3044 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 214.0+ KB

# %%
df['date'].dt.month_name()
# Out:
# Sr No
# 1       January
# 2       January
# 3       January
# 4       January
# 5       January
#          ...
# 3040    January
# 3041    January
# 3042    January
# 3043    January
# 3044    January
# Name: date, Length: 3044, dtype: object

# %%
df['Month_name'] = df['date'].dt.month_name()

# %%
df.sample(5)
# Out:
#             date            startup                                 vertical  \
# Sr No
# 411   2018-01-22           Skillate                               Technology
# 1468  2016-08-23            Octo.ai                               Technology
# 826   2017-05-16               Fynd                                eCommerce
# 492   2017-11-10  Happily Unmarried                                ECommerce
# 2620  2015-07-15            Mobikon  Restaurant customer engagement platform
#
#                                             subvertical       city  \
# Sr No
# 411                             Artificial Intellegence  Bengaluru
# 1468   Artificial Intelligence based marketing platform  New Delhi
# 826                            Fashion ECommerce Portal     Mumbai
# 492                             Online Gifting platform   Nw Delhi
# 2620                                                NaN       Pune
#
#                                                 investor           round  \
# Sr No
# ...

# %%
df.shape
# Out:
# (3044, 9)

# %%
df.isnull().sum()
# Out:
# date             8
# startup          0
# vertical       171
# subvertical    936
# city           180
# investor        24
# round            4
# amount           0
# Month_name       8
# dtype: int64

# %%
df = df.dropna(subset = ['date','vertical','city','investor','round','Month_name'])

# %%
df.shape
# Out:
# (2830, 9)

# %%
df.isnull().sum()
# Out:
# date           0
# startup        0
# vertical       0
# subvertical    0
# city           0
# investor       0
# round          0
# amount         0
# Month_name     0
# dtype: int64

# %%
df['subvertical'] =df['subvertical'].fillna('Unkown')

# %% [markdown]
# #EDA

# %%
df.sample(10)

# %%
#Recent 5 investemnet from the investors
df[df['investor'] == 'Ratan Tata']

# %%
df[df['investor'].str.contains('Ratan Tata')][['date','startup','vertical','city','round','amount','investor']]
# Out:
#             date             startup  \
# Sr No
# 348   2018-03-27           The Print
# 839   2017-05-23           The Print
# 1267  2016-10-04               GOQii
# 1368  2016-09-13          IdeaChakki
# 1591  2016-06-10           Kyazoonga
# 1595  2016-06-10        MadRat Games
# 1673  2016-05-04            Lenskart
# 1718  2016-05-19             Niki.ai
# 1789  2016-04-19            LensKart
# 1927  2016-02-08              Moglix
# 1934  2016-02-08   Invictus Oncology
# 1953  2016-02-15            Snapbizz
# 1969  2016-02-17  Bollant Industries
# 2002  2016-02-29            Nestaway
# 2007  2016-01-04             DogSpot
# 2015  2016-01-06              Tracxn
# 2061  2016-01-19            Cashkaro
# 2073  2016-01-21            FirstCry
# 2090  2016-01-27          Teabox.com
# 2152  2015-12-11           UrbanClap
# 2201  2015-11-03               Sabse
# 2269  2015-11-24         Crayon Data
# 2387  2015-09-02            HolaChef
# 2526  2015-08-17           YourStory
# ...

# %%
#Which sub sector had received the highest funding  (top 5)
df.groupby('subvertical')['amount'].sum().sort_values(ascending = False).head(3)

# %%
#Average Funding
df['amount'].mean()
# Out:
# 157.52063590785806

# %%
df['city'] = df['city'].str.replace('Bangalore','Bengaluru')
# Out:
# <ipython-input-288-8c77cb498006>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['city'] = df['city'].str.replace('Bangalore','Bengaluru')

# %%
#Which city has received the highest funding ?
df.groupby('city')['amount'].sum().sort_values(ascending = False).head(3)
# Out:
# city
# Bengaluru    195497.963111
# Mumbai        61679.830940
# New Delhi     53349.188192
# Name: amount, dtype: float64

# %%
#Recent 5 investemnet from the investors IDG Ventures with respect to city and amount spent
df[df['investor'].str.contains('IDG Ventures')]
# Out:
#             date                startup  \
# Sr No
# 102   2019-04-13                Tripoto
# 223   2018-07-30               Cure Fit
# 259   2018-05-02                Bizongo
# 310   2018-04-26                  POPxo
# 439   2017-12-07                eShakti
# 478   2017-11-04              Hevo Data
# 479   2017-11-06            Smart Karma
# 490   2017-11-09             Mobiliz AR
# 505   2017-11-21                 Heckyl
# 528   2017-10-05      Little Black Book
# 660   2017-08-21               Uniphore
# 673   2017-08-29                CureFit
# 699   2017-07-17                 Vayana
# 948   2017-03-07               Blowhorn
# 962   2017-03-16                 mPaani
# 964   2017-03-16                  POPxo
# 1012  2017-02-13               Sigtuple
# 1061  2017-01-12              Hansel.io
# 1202  2016-11-05                Bizongo
# 1211  2016-11-14              Active.ai
# 1215  2016-11-15             PlaySimple
# 1234  2016-11-23             Infisecure
# ...

# %%
#plot a graph to show how the investment in changing over the period of time for IDG Ventures

# %%
#number of unique startup ?

# %%
#plot a graph to
